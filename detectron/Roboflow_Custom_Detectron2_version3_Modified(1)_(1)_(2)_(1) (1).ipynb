# %% [markdown]
# # How to Train Detectron2 on Custom Objects
#
# This tutorial implements the new [Detectron2 Library](https://ai.facebook.com/blog/-detectron2-a-pytorch-based-modular-object-detection-library-/) by facebook. This notebook shows training on **your own custom objects** for object detection.
#
# It is worth noting that the Detectron2 library goes far beyond object detection, supporting semantic segmentation, keypoint detection, mask, and densepose.
#
#
# ### Accompanying Blog Post
#
# We recommend that you follow along in this notebook while reading the blog post on [how to train Detectron2](https://blog.roboflow.ai/how-to-train-detectron2/), concurrently.
#
# ### Steps Covered in this Tutorial
#
# In this tutorial, we will walk through the steps required to train Detectron2 on your custom objects. We use a [public blood cell detection dataset](https://public.roboflow.ai/object-detection/bccd), which is open source and free to use. You can also use this notebook on your own data.
#
# To train our detector we take the following steps:
#
# * Install Detectron2 dependencies
# * Download custom Detectron2 object detection data
# * Visualize Detectron2 training data
# * Write our Detectron2 Training configuration
# * Run Detectron2 training
# * Evaluate Detectron2 performance
# * Run Detectron2 inference on test images
#
#
#
# ### **About**
#
# [Roboflow](https://roboflow.ai) enables teams to deploy custom computer vision models quickly and accurately. Convert data from to annotation format, assess dataset health, preprocess, augment, and more. It's free for your first 1000 source images.
#
# #### ![Roboflow Workmark](https://i.imgur.com/WHFqYSJ.png)

# %% [markdown]
# # Install Detectron2 Dependencies

# %%
# install dependencies: (use cu101 because colab has CUDA 10.1)
# !pip install -U torch==1.5 torchvision==0.6 -f https://download.pytorch.org/whl/cu101/torch_stable.html
# !pip install cython pyyaml==5.1
# !pip install -U 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
import torch, torchvision
print(torch.__version__, torch.cuda.is_available())
# !gcc --version
# opencv is pre-installed on colab
# Out:
# Looking in links: https://download.pytorch.org/whl/cu101/torch_stable.html
# ERROR: Could not find a version that satisfies the requirement torch==1.5 (from versions: 1.11.0, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0)
# ERROR: No matching distribution found for torch==1.5
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (3.0.8)
# Collecting pyyaml==5.1
#   Downloading PyYAML-5.1.tar.gz (274 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.2/274.2 kB 1.5 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Collecting git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI
#   Cloning https://github.com/cocodataset/cocoapi.git to /tmp/pip-req-build-ita82w3r
#   Running command git clone --filter=blob:none --quiet https://github.com/cocodataset/cocoapi.git /tmp/pip-req-build-ita82w3r
#   Resolved https://github.com/cocodataset/cocoapi.git to commit 8c9bcc3cf640524c4c20a9c40e89cb6a2f2fa0e9
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools>=18.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools==2.0) (67.7.2)
# Requirement already satisfied: cython>=0.27.3 in /usr/local/lib/python3.10/dist-packages (from pycocotools==2.0) (3.0.8)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools==2.0) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools==2.0) (1.16.0)
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (setup.py) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp310-cp310-linux_x86_64.whl size=375548 sha256=34bb929383255834dc4e1d426395e2e670261cf4d981f086a9ae326bd87cbd74
#   Stored in directory: /tmp/pip-ephem-wheel-cache-roa5l_y4/wheels/39/61/b4/480fbddb4d3d6bc34083e7397bc6f5d1381f79acc68e9f3511
# Successfully built pycocotools
# Installing collected packages: pycocotools
#   Attempting uninstall: pycocotools
#     Found existing installation: pycocotools 2.0.7
#     Uninstalling pycocotools-2.0.7:
#       Successfully uninstalled pycocotools-2.0.7
# Successfully installed pycocotools-2.0
# 2.1.0+cu121 True
# gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
# Copyright (C) 2021 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# install detectron2:
# !pip install detectron2==0.1.3 -f https://dl.fbaipublicfiles.com/detectron2/wheels/cu101/torch1.5/index.html
# Out:
# Looking in links: https://dl.fbaipublicfiles.com/detectron2/wheels/cu101/torch1.5/index.html
# ERROR: Could not find a version that satisfies the requirement detectron2==0.1.3 (from versions: none)
# ERROR: No matching distribution found for detectron2==0.1.3

# %%
# !python -m pip install 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# Collecting git+https://github.com/facebookresearch/detectron2.git
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-yhesu1dt
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-yhesu1dt
#   Resolved https://github.com/facebookresearch/detectron2.git to commit 3ff5dd1cff4417af07097064813c9f28d7461d3c
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (3.7.1)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.0.7)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.4.0)
# Collecting yacs>=0.1.8 (from detectron2==0.6)
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (0.9.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.2.1)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (4.66.2)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.15.2)
# Collecting fvcore<0.1.6,>=0.1.5 (from detectron2==0.6)
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting iopath<0.1.10,>=0.1.7 (from detectron2==0.6)
#   Downloading iopath-0.1.9-py3-none-any.whl (27 kB)
# Collecting omegaconf<2.4,>=2.1 (from detectron2==0.6)
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.1 MB/s eta 0:00:00
# Collecting hydra-core>=1.1 (from detectron2==0.6)
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 16.9 MB/s eta 0:00:00
# Collecting black (from detectron2==0.6)
#   Downloading black-24.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 41.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (23.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (1.25.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (6.0.1)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.1->detectron2==0.6)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 15.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting portalocker (from iopath<0.1.10,>=0.1.7->detectron2==0.6)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (2.8.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (8.1.7)
# Collecting mypy-extensions>=0.4.3 (from black->detectron2==0.6)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting pathspec>=0.9.0 (from black->detectron2==0.6)
#   Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (4.2.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (2.0.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (4.9.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.60.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.5.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (67.7.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard->detectron2==0.6) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (2.1.5)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard->detectron2==0.6) (3.2.2)
# Building wheels for collected packages: detectron2, fvcore, antlr4-python3-runtime
#   Building wheel for detectron2 (setup.py) ... done
#   Created wheel for detectron2: filename=detectron2-0.6-cp310-cp310-linux_x86_64.whl size=6122849 sha256=7f39b545c57e90d2cdd2c6c186c9701a2212a1794fe7a89829b598863db40ed0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-24q0jadw/wheels/47/e5/15/94c80df2ba85500c5d76599cc307c0a7079d0e221bb6fc4375
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61400 sha256=a5a391d569e78d5aeeb6c89681cdf75303b89308d800fc0488376a2b3cbd6722
#   Stored in directory: /root/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=4e08023e7bcf2e681a93d92709c091792528783ed2c4cc6f749f808e78c1d16a
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built detectron2 fvcore antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, yacs, portalocker, pathspec, omegaconf, mypy-extensions, iopath, hydra-core, black, fvcore, detectron2
# Successfully installed antlr4-python3-runtime-4.9.3 black-24.2.0 detectron2-0.6 fvcore-0.1.5.post20221221 hydra-core-1.3.2 iopath-0.1.9 mypy-extensions-1.0.0 omegaconf-2.3.0 pathspec-0.12.1 portalocker-2.8.2 yacs-0.1.8

# %%
# You may need to restart your runtime prior to this, to let your installation take effect
# Some basic setup:
# Setup detectron2 logger
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import cv2
import random
from google.colab.patches import cv2_imshow

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog
from detectron2.data.catalog import DatasetCatalog

# %% [markdown]
# # Import and Register Custom Detectron2 Data

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="rSyKqK8ZleKk72WAPmw3")
project = rf.workspace("object-detection-vmxxo").project("object-detection-ltqfj")
dataset = project.version(9).download("coco")
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.19-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.2/70.2 kB 2.2 MB/s eta 0:00:00
# Collecting certifi==2023.7.22 (from roboflow)
#   Downloading certifi-2023.7.22-py3-none-any.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 7.2 MB/s eta 0:00:00
# Collecting chardet==4.0.0 (from roboflow)
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 19.7 MB/s eta 0:00:00
# Collecting cycler==0.10.0 (from roboflow)
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting idna==2.10 (from roboflow)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.25.2)
# Collecting opencv-python-headless==4.8.0.74 (from roboflow)
#   Downloading opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 33.0 MB/s eta 0:00:00
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Collecting supervision (from roboflow)
#   Downloading supervision-0.18.0-py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 12.7 MB/s eta 0:00:00
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.0.7)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.2)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.6 MB/s eta 0:00:00
# Collecting python-magic (from roboflow)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.49.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.3.2)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from supervision->roboflow) (0.7.1)
# Requirement already satisfied: scipy<2.0.0,>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from supervision->roboflow) (1.11.4)
# Installing collected packages: python-magic, python-dotenv, opencv-python-headless, idna, cycler, chardet, certifi, supervision, requests-toolbelt, roboflow
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2024.2.2
#     Uninstalling certifi-2024.2.2:
#       Successfully uninstalled certifi-2024.2.2
# Successfully installed certifi-2023.7.22 chardet-4.0.0 cycler-0.10.0 idna-2.10 opencv-python-headless-4.8.0.74 python-dotenv-1.0.1 python-magic-0.4.27 requests-toolbelt-1.0.0 roboflow-1.1.19 supervision-0.18.0
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Object-Detection-9 to coco:: 100%|██████████| 2374/2374 [00:01<00:00, 2148.97it/s]
# Extracting Dataset Version Zip to Object-Detection-9 in coco:: 100%|██████████| 96/96 [00:00<00:00, 4063.39it/s]

# %%
from detectron2.data.datasets import register_coco_instances
register_coco_instances("my_dataset_train", {}, "/content/train/_annotations.coco.json", "/content/train")
register_coco_instances("my_dataset_val", {}, "/content/valid/_annotations.coco.json", "/content/valid")
register_coco_instances("my_dataset_test", {}, "/content/test/_annotations.coco.json", "/content/test")

# %%
#visualize training data
my_dataset_train_metadata = MetadataCatalog.get("my_dataset_train")
dataset_dicts = DatasetCatalog.get("my_dataset_train")

import random
from detectron2.utils.visualizer import Visualizer

for d in random.sample(dataset_dicts, 3):
    img = cv2.imread(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=my_dataset_train_metadata, scale=0.5)
    vis = visualizer.draw_dataset_dict(d)
    cv2_imshow(vis.get_image()[:, :, ::-1])
# Out:
# WARNING [02/26 07:21:34 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [02/26 07:21:34 d2.data.datasets.coco]: Loaded 76 images in COCO format from /content/train/_annotations.coco.json
# <PIL.Image.Image image mode=RGB size=320x320>
# <PIL.Image.Image image mode=RGB size=320x320>
# <PIL.Image.Image image mode=RGB size=320x320>

# %%
#visualize training data
my_dataset_train_metadata = MetadataCatalog.get("my_dataset_train")
dataset_dicts = DatasetCatalog.get("my_dataset_train")

import random
from detectron2.utils.visualizer import Visualizer

for d in random.sample(dataset_dicts, 3):
    img = cv2.imread(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=my_dataset_train_metadata, scale=0.5)
    vis = visualizer.draw_dataset_dict(d)
    cv2_imshow(vis.get_image()[:, :, ::-1])
# Out:
# WARNING [02/26 07:21:36 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [02/26 07:21:36 d2.data.datasets.coco]: Loaded 76 images in COCO format from /content/train/_annotations.coco.json
# <PIL.Image.Image image mode=RGB size=320x320>
# <PIL.Image.Image image mode=RGB size=320x320>
# <PIL.Image.Image image mode=RGB size=320x320>

# %% [markdown]
# # Train Custom Detectron2 Detector

# %%
#We are importing our own Trainer Module here to use the COCO validation evaluation during training. Otherwise no validation eval occurs.

from detectron2.engine import DefaultTrainer
from detectron2.evaluation import COCOEvaluator

class CocoTrainer(DefaultTrainer):

  @classmethod
  def build_evaluator(cls, cfg, dataset_name, output_folder=None):

    if output_folder is None:
        os.makedirs("coco_eval", exist_ok=True)
        output_folder = "coco_eval"

    return COCOEvaluator(dataset_name, cfg, False, output_folder)

# %%
# !apt-get update
# !apt-get install -y nvidia-driver-470

# %%
! add-apt-repository ppa:graphics-drivers/ppa
! apt update
! apt install nvidia-384 nvidia-384-dev
! apt-get install g++ freeglut3-dev build-essential libx11-dev libxmu-dev libxi-dev libglu1-mesa libglu1-mesa-dev

# %%
! nvidia-smi

# %%
#from .detectron2.tools.train_net import Trainer
#from detectron2.engine import DefaultTrainer
# select from modelzoo here: https://github.com/facebookresearch/detectron2/blob/master/MODEL_ZOO.md#coco-object-detection-baselines

from detectron2.config import get_cfg
#from detectron2.evaluation.coco_evaluation import COCOEvaluator
import os

cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/faster_rcnn_X_101_32x8d_FPN_3x.yaml"))
cfg.DATASETS.TRAIN = ("my_dataset_train",)
cfg.DATASETS.TEST = ("my_dataset_val",)

cfg.DATALOADER.NUM_WORKERS = 4
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-Detection/faster_rcnn_X_101_32x8d_FPN_3x.yaml")  # Let training initialize from model zoo
cfg.SOLVER.IMS_PER_BATCH = 5
cfg.SOLVER.BASE_LR = 0.001


cfg.SOLVER.WARMUP_ITERS = 1000
cfg.SOLVER.MAX_ITER = 1500 #adjust up if val mAP is still rising, adjust down if overfit
cfg.SOLVER.STEPS = (1000, 1100)
cfg.SOLVER.GAMMA = 0.05




cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 64
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 6 #your number of classes + 1

cfg.TEST.EVAL_PERIOD = 500


os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = CocoTrainer(cfg)
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# [02/26 07:21:42 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (6): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (7): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (8): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (9): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (10): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (11): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (12): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (13): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (14): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (15): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (16): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (17): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (18): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (19): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (20): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (21): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (22): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=7, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=24, bias=True)
#     )
#   )
# )
# WARNING [02/26 07:21:42 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [02/26 07:21:42 d2.data.datasets.coco]: Loaded 76 images in COCO format from /content/train/_annotations.coco.json
# [02/26 07:21:42 d2.data.build]: Removed 2 images with no usable annotations. 74 images left.
# [02/26 07:21:42 d2.data.build]: Distribution of instances among all 6 categories:
# |   category   | #instances   |   category    | #instances   |  category   | #instances   |
# |:------------:|:-------------|:-------------:|:-------------|:-----------:|:-------------|
# |   symbols    | 0            |  Gate_valve   | 46           | S_21_Flange | 44           |
# | S_28_SDL-DDL | 28           | Sliding_valve | 38           |     th      | 40           |
# |              |              |               |              |             |              |
# |    total     | 196          |               |              |             |              |
# [02/26 07:21:42 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [02/26 07:21:42 d2.data.build]: Using training sampler TrainingSampler
# [02/26 07:21:42 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/26 07:21:42 d2.data.common]: Serializing 74 elements to byte tensors and concatenating them all ...
# [02/26 07:21:42 d2.data.common]: Serialized dataset takes 0.02 MiB
# [02/26 07:21:42 d2.data.build]: Making batched data loader with batch_size=5
# [02/26 07:21:42 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-Detection/faster_rcnn_X_101_32x8d_FPN_3x/139173657/model_final_68b088.pkl ...
# model_final_68b088.pkl: 421MB [00:03, 109MB/s]
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (7, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (7,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (24, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (24,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# [02/26 07:21:46 d2.engine.train_loop]: Starting training from iteration 0
# torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
# [02/26 07:22:15 d2.utils.events]:  eta: 0:30:43  iter: 19  total_loss: 2.477  loss_cls: 1.681  loss_box_reg: 0.5184  loss_rpn_cls: 0.2744  loss_rpn_loc: 0.01754    time: 1.2229  last_time: 1.0981  data_time: 0.0288  last_data_time: 0.0165   lr: 1.931e-06  max_mem: 8349M
# [02/26 07:22:42 d2.utils.events]:  eta: 0:30:20  iter: 39  total_loss: 2.511  loss_cls: 1.627  loss_box_reg: 0.6149  loss_rpn_cls: 0.3094  loss_rpn_loc: 0.02041    time: 1.2202  last_time: 1.2545  data_time: 0.0212  last_data_time: 0.0290   lr: 2.911e-06  max_mem: 8349M
# [02/26 07:23:06 d2.utils.events]:  eta: 0:29:54  iter: 59  total_loss: 2.367  loss_cls: 1.533  loss_box_reg: 0.5686  loss_rpn_cls: 0.2453  loss_rpn_loc: 0.01951    time: 1.2135  last_time: 1.2587  data_time: 0.0196  last_data_time: 0.0195   lr: 3.891e-06  max_mem: 8349M
# [02/26 07:23:30 d2.utils.events]:  eta: 0:29:29  iter: 79  total_loss: 2.262  loss_cls: 1.422  loss_box_reg: 0.5548  loss_rpn_cls: 0.2375  loss_rpn_loc: 0.02098    time: 1.2138  last_time: 1.1534  data_time: 0.0206  last_data_time: 0.0173   lr: 4.871e-06  max_mem: 8349M
# [02/26 07:23:54 d2.utils.events]:  eta: 0:29:07  iter: 99  total_loss: 2.226  loss_cls: 1.304  loss_box_reg: 0.6309  loss_rpn_cls: 0.1926  loss_rpn_loc: 0.01857    time: 1.2160  last_time: 1.2600  data_time: 0.0214  last_data_time: 0.0302   lr: 5.851e-06  max_mem: 8349M
# [02/26 07:24:18 d2.utils.events]:  eta: 0:28:41  iter: 119  total_loss: 2.053  loss_cls: 1.195  loss_box_reg: 0.6504  loss_rpn_cls: 0.1927  loss_rpn_loc: 0.01776    time: 1.2135  last_time: 1.1535  data_time: 0.0206  last_data_time: 0.0238   lr: 6.831e-06  max_mem: 8349M
# [02/26 07:24:42 d2.utils.events]:  eta: 0:28:15  iter: 139  total_loss: 1.948  loss_cls: 1.061  loss_box_reg: 0.6751  loss_rpn_cls: 0.1595  loss_rpn_loc: 0.01739    time: 1.2081  last_time: 1.2537  data_time: 0.0202  last_data_time: 0.0250   lr: 7.811e-06  max_mem: 8349M
# [02/26 07:25:06 d2.utils.events]:  eta: 0:27:50  iter: 159  total_loss: 1.918  loss_cls: 1.017  loss_box_reg: 0.7091  loss_rpn_cls: 0.15  loss_rpn_loc: 0.0199    time: 1.2056  last_time: 1.2487  data_time: 0.0211  last_data_time: 0.0196   lr: 8.791e-06  max_mem: 8349M
# [02/26 07:25:30 d2.utils.events]:  eta: 0:27:25  iter: 179  total_loss: 1.77  loss_cls: 0.9251  loss_box_reg: 0.7361  loss_rpn_cls: 0.1063  loss_rpn_loc: 0.01848    time: 1.2055  last_time: 1.2466  data_time: 0.0212  last_data_time: 0.0197   lr: 9.771e-06  max_mem: 8349M
# [02/26 07:25:54 d2.utils.events]:  eta: 0:27:00  iter: 199  total_loss: 1.815  loss_cls: 0.8935  loss_box_reg: 0.7805  loss_rpn_cls: 0.09209  loss_rpn_loc: 0.01821    time: 1.2055  last_time: 1.0751  data_time: 0.0209  last_data_time: 0.0215   lr: 1.0751e-05  max_mem: 8349M
# [02/26 07:26:18 d2.utils.events]:  eta: 0:26:35  iter: 219  total_loss: 1.808  loss_cls: 0.885  loss_box_reg: 0.7985  loss_rpn_cls: 0.08718  loss_rpn_loc: 0.01829    time: 1.2050  last_time: 1.1586  data_time: 0.0211  last_data_time: 0.0184   lr: 1.1731e-05  max_mem: 8349M
# [02/26 07:26:42 d2.utils.events]:  eta: 0:26:10  iter: 239  total_loss: 1.728  loss_cls: 0.8306  loss_box_reg: 0.8166  loss_rpn_cls: 0.06211  loss_rpn_loc: 0.01478    time: 1.2055  last_time: 1.0763  data_time: 0.0214  last_data_time: 0.0218   lr: 1.2711e-05  max_mem: 8349M
# [02/26 07:27:06 d2.utils.events]:  eta: 0:25:45  iter: 259  total_loss: 1.719  loss_cls: 0.8246  loss_box_reg: 0.8152  loss_rpn_cls: 0.05449  loss_rpn_loc: 0.017    time: 1.2041  last_time: 1.1585  data_time: 0.0205  last_data_time: 0.0207   lr: 1.3691e-05  max_mem: 8349M
# [02/26 07:27:30 d2.utils.events]:  eta: 0:25:20  iter: 279  total_loss: 1.717  loss_cls: 0.807  loss_box_reg: 0.8524  loss_rpn_cls: 0.04773  loss_rpn_loc: 0.01891    time: 1.2042  last_time: 1.2467  data_time: 0.0197  last_data_time: 0.0209   lr: 1.4671e-05  max_mem: 8349M
# [02/26 07:27:54 d2.utils.events]:  eta: 0:24:55  iter: 299  total_loss: 1.654  loss_cls: 0.7777  loss_box_reg: 0.8271  loss_rpn_cls: 0.02915  loss_rpn_loc: 0.01711    time: 1.2037  last_time: 1.0738  data_time: 0.0212  last_data_time: 0.0207   lr: 1.5651e-05  max_mem: 8349M
# [02/26 07:28:18 d2.utils.events]:  eta: 0:24:30  iter: 319  total_loss: 1.673  loss_cls: 0.7735  loss_box_reg: 0.83  loss_rpn_cls: 0.03065  loss_rpn_loc: 0.01755    time: 1.2034  last_time: 1.2527  data_time: 0.0201  last_data_time: 0.0201   lr: 1.6631e-05  max_mem: 8349M
# [02/26 07:28:42 d2.utils.events]:  eta: 0:24:05  iter: 339  total_loss: 1.638  loss_cls: 0.743  loss_box_reg: 0.8435  loss_rpn_cls: 0.01908  loss_rpn_loc: 0.01633    time: 1.2026  last_time: 1.2463  data_time: 0.0209  last_data_time: 0.0181   lr: 1.7611e-05  max_mem: 8349M
# [02/26 07:29:06 d2.utils.events]:  eta: 0:23:40  iter: 359  total_loss: 1.649  loss_cls: 0.7602  loss_box_reg: 0.8518  loss_rpn_cls: 0.01871  loss_rpn_loc: 0.01713    time: 1.2029  last_time: 1.0795  data_time: 0.0203  last_data_time: 0.0228   lr: 1.8591e-05  max_mem: 8349M
# [02/26 07:29:30 d2.utils.events]:  eta: 0:23:15  iter: 379  total_loss: 1.644  loss_cls: 0.7434  loss_box_reg: 0.8503  loss_rpn_cls: 0.01356  loss_rpn_loc: 0.01575    time: 1.2027  last_time: 1.1470  data_time: 0.0192  last_data_time: 0.0169   lr: 1.9571e-05  max_mem: 8349M
# [02/26 07:29:54 d2.utils.events]:  eta: 0:22:51  iter: 399  total_loss: 1.638  loss_cls: 0.7249  loss_box_reg: 0.8612  loss_rpn_cls: 0.01389  loss_rpn_loc: 0.01487    time: 1.2030  last_time: 1.2489  data_time: 0.0208  last_data_time: 0.0211   lr: 2.0551e-05  max_mem: 8349M
# [02/26 07:30:18 d2.utils.events]:  eta: 0:22:26  iter: 419  total_loss: 1.61  loss_cls: 0.727  loss_box_reg: 0.8579  loss_rpn_cls: 0.01108  loss_rpn_loc: 0.0144    time: 1.2028  last_time: 1.0734  data_time: 0.0194  last_data_time: 0.0187   lr: 2.1531e-05  max_mem: 8349M
# [02/26 07:30:42 d2.utils.events]:  eta: 0:22:01  iter: 439  total_loss: 1.614  loss_cls: 0.687  loss_box_reg: 0.8645  loss_rpn_cls: 0.01188  loss_rpn_loc: 0.01495    time: 1.2034  last_time: 1.1551  data_time: 0.0216  last_data_time: 0.0260   lr: 2.2511e-05  max_mem: 8349M
# [02/26 07:31:07 d2.utils.events]:  eta: 0:21:36  iter: 459  total_loss: 1.583  loss_cls: 0.6912  loss_box_reg: 0.8517  loss_rpn_cls: 0.01059  loss_rpn_loc: 0.0139    time: 1.2038  last_time: 1.1493  data_time: 0.0207  last_data_time: 0.0201   lr: 2.3491e-05  max_mem: 8349M
# [02/26 07:31:30 d2.utils.events]:  eta: 0:21:11  iter: 479  total_loss: 1.561  loss_cls: 0.6832  loss_box_reg: 0.8468  loss_rpn_cls: 0.01013  loss_rpn_loc: 0.01616    time: 1.2025  last_time: 1.2506  data_time: 0.0216  last_data_time: 0.0229   lr: 2.4471e-05  max_mem: 8349M
# WARNING [02/26 07:31:54 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [02/26 07:31:54 d2.data.datasets.coco]: Loaded 5 images in COCO format from /content/valid/_annotations.coco.json
# [02/26 07:31:54 d2.data.build]: Distribution of instances among all 6 categories:
# |   category   | #instances   |   category    | #instances   |  category   | #instances   |
# |:------------:|:-------------|:-------------:|:-------------|:-----------:|:-------------|
# |   symbols    | 0            |  Gate_valve   | 8            | S_21_Flange | 2            |
# | S_28_SDL-DDL | 1            | Sliding_valve | 2            |     th      | 0            |
# |              |              |               |              |             |              |
# |    total     | 13           |               |              |             |              |
# [02/26 07:31:54 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/26 07:31:54 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/26 07:31:54 d2.data.common]: Serializing 5 elements to byte tensors and concatenating them all ...
# [02/26 07:31:54 d2.data.common]: Serialized dataset takes 0.00 MiB
# WARNING [02/26 07:31:54 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [02/26 07:31:54 d2.evaluation.evaluator]: Start inference on 5 batches
# [02/26 07:31:55 d2.evaluation.evaluator]: Total inference time: 0:00:00.104580 (0.104580 s / iter per device, on 1 devices)
# [02/26 07:31:55 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:00 (0.072636 s / iter per device, on 1 devices)
# [02/26 07:31:55 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/26 07:31:55 d2.evaluation.coco_evaluation]: Saving results to coco_eval/coco_instances_results.json
# [02/26 07:31:55 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [02/26 07:31:55 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [02/26 07:31:55 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.01 seconds.
# [02/26 07:31:55 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [02/26 07:31:55 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.180
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.454
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.126
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.187
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.181
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.359
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.381
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.250
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.439
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# [02/26 07:31:55 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl  |
# |:------:|:------:|:------:|:------:|:------:|:-----:|
# | 18.024 | 45.431 | 0.798  | 12.568 | 18.700 |  nan  |
# [02/26 07:31:55 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/26 07:31:55 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category     | AP     | category      | AP    | category    | AP     |
# |:-------------|:-------|:--------------|:------|:------------|:-------|
# | symbols      | nan    | Gate_valve    | 1.946 | S_21_Flange | 20.198 |
# | S_28_SDL-DDL | 40.000 | Sliding_valve | 9.953 | th          | nan    |
# [02/26 07:31:55 d2.engine.defaults]: Evaluation results for my_dataset_val in csv format:
# [02/26 07:31:55 d2.evaluation.testing]: copypaste: Task: bbox
# [02/26 07:31:55 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/26 07:31:55 d2.evaluation.testing]: copypaste: 18.0244,45.4315,0.7981,12.5675,18.6995,nan
# [02/26 07:31:55 d2.utils.events]:  eta: 0:20:46  iter: 499  total_loss: 1.545  loss_cls: 0.6692  loss_box_reg: 0.8505  loss_rpn_cls: 0.00936  loss_rpn_loc: 0.01431    time: 1.2027  last_time: 1.0841  data_time: 0.0213  last_data_time: 0.0203   lr: 2.5451e-05  max_mem: 8349M
# [02/26 07:32:18 d2.utils.events]:  eta: 0:20:21  iter: 519  total_loss: 1.568  loss_cls: 0.6542  loss_box_reg: 0.8639  loss_rpn_cls: 0.008737  loss_rpn_loc: 0.01443    time: 1.2008  last_time: 1.0742  data_time: 0.0209  last_data_time: 0.0192   lr: 2.6431e-05  max_mem: 8349M
# [02/26 07:32:42 d2.utils.events]:  eta: 0:19:56  iter: 539  total_loss: 1.513  loss_cls: 0.6318  loss_box_reg: 0.8581  loss_rpn_cls: 0.008124  loss_rpn_loc: 0.01252    time: 1.2007  last_time: 1.0970  data_time: 0.0212  last_data_time: 0.0256   lr: 2.7411e-05  max_mem: 8349M
# [02/26 07:33:06 d2.utils.events]:  eta: 0:19:31  iter: 559  total_loss: 1.506  loss_cls: 0.6321  loss_box_reg: 0.8475  loss_rpn_cls: 0.009864  loss_rpn_loc: 0.01424    time: 1.2012  last_time: 1.2583  data_time: 0.0202  last_data_time: 0.0194   lr: 2.8391e-05  max_mem: 8349M
# [02/26 07:33:30 d2.utils.events]:  eta: 0:19:06  iter: 579  total_loss: 1.496  loss_cls: 0.6205  loss_box_reg: 0.8547  loss_rpn_cls: 0.005826  loss_rpn_loc: 0.0116    time: 1.2010  last_time: 1.2662  data_time: 0.0207  last_data_time: 0.0269   lr: 2.9371e-05  max_mem: 8349M
# [02/26 07:33:54 d2.utils.events]:  eta: 0:18:41  iter: 599  total_loss: 1.487  loss_cls: 0.6156  loss_box_reg: 0.8402  loss_rpn_cls: 0.007247  loss_rpn_loc: 0.01301    time: 1.2004  last_time: 1.2609  data_time: 0.0211  last_data_time: 0.0247   lr: 3.0351e-05  max_mem: 8349M
# [02/26 07:34:19 d2.utils.events]:  eta: 0:18:16  iter: 619  total_loss: 1.444  loss_cls: 0.5898  loss_box_reg: 0.8427  loss_rpn_cls: 0.007513  loss_rpn_loc: 0.0138    time: 1.2013  last_time: 1.2506  data_time: 0.0210  last_data_time: 0.0210   lr: 3.1331e-05  max_mem: 8349M
# [02/26 07:34:43 d2.utils.events]:  eta: 0:17:52  iter: 639  total_loss: 1.441  loss_cls: 0.5667  loss_box_reg: 0.8436  loss_rpn_cls: 0.007323  loss_rpn_loc: 0.01367    time: 1.2019  last_time: 1.1508  data_time: 0.0205  last_data_time: 0.0200   lr: 3.2311e-05  max_mem: 8349M
# [02/26 07:35:07 d2.utils.events]:  eta: 0:17:27  iter: 659  total_loss: 1.432  loss_cls: 0.5473  loss_box_reg: 0.8309  loss_rpn_cls: 0.006443  loss_rpn_loc: 0.01299    time: 1.2015  last_time: 1.2514  data_time: 0.0212  last_data_time: 0.0209   lr: 3.3291e-05  max_mem: 8349M
# [02/26 07:35:31 d2.utils.events]:  eta: 0:17:02  iter: 679  total_loss: 1.378  loss_cls: 0.5278  loss_box_reg: 0.8193  loss_rpn_cls: 0.006107  loss_rpn_loc: 0.01176    time: 1.2014  last_time: 1.2492  data_time: 0.0207  last_data_time: 0.0154   lr: 3.4271e-05  max_mem: 8349M
# [02/26 07:35:55 d2.utils.events]:  eta: 0:16:37  iter: 699  total_loss: 1.348  loss_cls: 0.5291  loss_box_reg: 0.8173  loss_rpn_cls: 0.007776  loss_rpn_loc: 0.01477    time: 1.2020  last_time: 1.2446  data_time: 0.0194  last_data_time: 0.0165   lr: 3.5251e-05  max_mem: 8349M
# [02/26 07:36:19 d2.utils.events]:  eta: 0:16:12  iter: 719  total_loss: 1.324  loss_cls: 0.4852  loss_box_reg: 0.8163  loss_rpn_cls: 0.005861  loss_rpn_loc: 0.01428    time: 1.2010  last_time: 1.2632  data_time: 0.0212  last_data_time: 0.0243   lr: 3.6231e-05  max_mem: 8349M
# [02/26 07:36:42 d2.utils.events]:  eta: 0:15:47  iter: 739  total_loss: 1.313  loss_cls: 0.4804  loss_box_reg: 0.8076  loss_rpn_cls: 0.004824  loss_rpn_loc: 0.0118    time: 1.2006  last_time: 1.0787  data_time: 0.0215  last_data_time: 0.0254   lr: 3.7211e-05  max_mem: 8349M
# [02/26 07:37:06 d2.utils.events]:  eta: 0:15:22  iter: 759  total_loss: 1.251  loss_cls: 0.4447  loss_box_reg: 0.7872  loss_rpn_cls: 0.006421  loss_rpn_loc: 0.0125    time: 1.1997  last_time: 1.0809  data_time: 0.0205  last_data_time: 0.0235   lr: 3.8191e-05  max_mem: 8349M
# [02/26 07:37:29 d2.utils.events]:  eta: 0:14:57  iter: 779  total_loss: 1.324  loss_cls: 0.4518  loss_box_reg: 0.8115  loss_rpn_cls: 0.006254  loss_rpn_loc: 0.01479    time: 1.1994  last_time: 1.2620  data_time: 0.0203  last_data_time: 0.0221   lr: 3.9171e-05  max_mem: 8349M
# [02/26 07:37:54 d2.utils.events]:  eta: 0:14:32  iter: 799  total_loss: 1.221  loss_cls: 0.4022  loss_box_reg: 0.7869  loss_rpn_cls: 0.005125  loss_rpn_loc: 0.01288    time: 1.1998  last_time: 1.1654  data_time: 0.0202  last_data_time: 0.0246   lr: 4.0151e-05  max_mem: 8349M
# [02/26 07:38:18 d2.utils.events]:  eta: 0:14:07  iter: 819  total_loss: 1.189  loss_cls: 0.391  loss_box_reg: 0.7689  loss_rpn_cls: 0.005702  loss_rpn_loc: 0.01198    time: 1.2005  last_time: 1.2579  data_time: 0.0203  last_data_time: 0.0193   lr: 4.1131e-05  max_mem: 8349M
# [02/26 07:38:43 d2.utils.events]:  eta: 0:13:42  iter: 839  total_loss: 1.174  loss_cls: 0.3839  loss_box_reg: 0.7708  loss_rpn_cls: 0.005107  loss_rpn_loc: 0.01238    time: 1.2008  last_time: 1.2561  data_time: 0.0215  last_data_time: 0.0258   lr: 4.2111e-05  max_mem: 8349M
# [02/26 07:39:07 d2.utils.events]:  eta: 0:13:17  iter: 859  total_loss: 1.103  loss_cls: 0.3501  loss_box_reg: 0.7301  loss_rpn_cls: 0.006817  loss_rpn_loc: 0.01416    time: 1.2011  last_time: 1.2562  data_time: 0.0208  last_data_time: 0.0186   lr: 4.3091e-05  max_mem: 8349M
# [02/26 07:39:31 d2.utils.events]:  eta: 0:12:52  iter: 879  total_loss: 1.084  loss_cls: 0.3395  loss_box_reg: 0.7342  loss_rpn_cls: 0.005471  loss_rpn_loc: 0.01219    time: 1.2013  last_time: 1.2552  data_time: 0.0210  last_data_time: 0.0196   lr: 4.4071e-05  max_mem: 8349M
# [02/26 07:39:55 d2.utils.events]:  eta: 0:12:28  iter: 899  total_loss: 1.015  loss_cls: 0.3027  loss_box_reg: 0.6959  loss_rpn_cls: 0.002474  loss_rpn_loc: 0.01427    time: 1.2015  last_time: 1.2594  data_time: 0.0207  last_data_time: 0.0245   lr: 4.5051e-05  max_mem: 8349M
# [02/26 07:40:20 d2.utils.events]:  eta: 0:12:03  iter: 919  total_loss: 0.9957  loss_cls: 0.2719  loss_box_reg: 0.6877  loss_rpn_cls: 0.002157  loss_rpn_loc: 0.0129    time: 1.2018  last_time: 1.2489  data_time: 0.0207  last_data_time: 0.0166   lr: 4.6031e-05  max_mem: 8349M
# [02/26 07:40:44 d2.utils.events]:  eta: 0:11:38  iter: 939  total_loss: 0.9348  loss_cls: 0.2619  loss_box_reg: 0.6687  loss_rpn_cls: 0.00154  loss_rpn_loc: 0.015    time: 1.2020  last_time: 1.2425  data_time: 0.0219  last_data_time: 0.0153   lr: 4.7011e-05  max_mem: 8349M
# [02/26 07:41:08 d2.utils.events]:  eta: 0:11:13  iter: 959  total_loss: 0.9408  loss_cls: 0.2675  loss_box_reg: 0.6616  loss_rpn_cls: 0.005618  loss_rpn_loc: 0.01291    time: 1.2017  last_time: 0.9926  data_time: 0.0203  last_data_time: 0.0226   lr: 4.7991e-05  max_mem: 8349M
# [02/26 07:41:32 d2.utils.events]:  eta: 0:10:48  iter: 979  total_loss: 0.854  loss_cls: 0.2098  loss_box_reg: 0.6166  loss_rpn_cls: 0.004206  loss_rpn_loc: 0.01229    time: 1.2015  last_time: 1.2494  data_time: 0.0204  last_data_time: 0.0213   lr: 4.8971e-05  max_mem: 8349M
# WARNING [02/26 07:41:55 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [02/26 07:41:55 d2.data.datasets.coco]: Loaded 5 images in COCO format from /content/valid/_annotations.coco.json
# [02/26 07:41:55 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/26 07:41:55 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/26 07:41:55 d2.data.common]: Serializing 5 elements to byte tensors and concatenating them all ...
# [02/26 07:41:55 d2.data.common]: Serialized dataset takes 0.00 MiB
# WARNING [02/26 07:41:55 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [02/26 07:41:55 d2.evaluation.evaluator]: Start inference on 5 batches
# [02/26 07:41:56 d2.evaluation.evaluator]: Total inference time: 0:00:00.113873 (0.113873 s / iter per device, on 1 devices)
# [02/26 07:41:56 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:00 (0.071728 s / iter per device, on 1 devices)
# [02/26 07:41:56 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/26 07:41:56 d2.evaluation.coco_evaluation]: Saving results to coco_eval/coco_instances_results.json
# [02/26 07:41:56 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [02/26 07:41:56 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [02/26 07:41:56 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.00 seconds.
# [02/26 07:41:56 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [02/26 07:41:56 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.470
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.875
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.513
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.464
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.476
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.447
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.594
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.594
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.525
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.639
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# [02/26 07:41:56 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl  |
# |:------:|:------:|:------:|:------:|:------:|:-----:|
# | 47.025 | 87.525 | 51.279 | 46.436 | 47.555 |  nan  |
# [02/26 07:41:56 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/26 07:41:56 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category     | AP     | category      | AP     | category    | AP     |
# |:-------------|:-------|:--------------|:-------|:------------|:-------|
# | symbols      | nan    | Gate_valve    | 30.427 | S_21_Flange | 45.149 |
# | S_28_SDL-DDL | 80.000 | Sliding_valve | 32.525 | th          | nan    |
# [02/26 07:41:56 d2.engine.defaults]: Evaluation results for my_dataset_val in csv format:
# [02/26 07:41:56 d2.evaluation.testing]: copypaste: Task: bbox
# [02/26 07:41:56 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/26 07:41:56 d2.evaluation.testing]: copypaste: 47.0250,87.5248,51.2789,46.4356,47.5549,nan
# [02/26 07:41:56 d2.utils.events]:  eta: 0:10:23  iter: 999  total_loss: 0.8346  loss_cls: 0.2123  loss_box_reg: 0.5955  loss_rpn_cls: 0.003901  loss_rpn_loc: 0.01456    time: 1.2012  last_time: 1.2579  data_time: 0.0201  last_data_time: 0.0186   lr: 4.9951e-05  max_mem: 8349M
# [02/26 07:42:20 d2.utils.events]:  eta: 0:09:58  iter: 1019  total_loss: 0.7352  loss_cls: 0.1952  loss_box_reg: 0.5478  loss_rpn_cls: 0.002772  loss_rpn_loc: 0.01336    time: 1.2014  last_time: 1.2522  data_time: 0.0200  last_data_time: 0.0241   lr: 5e-05  max_mem: 8349M
# [02/26 07:42:44 d2.utils.events]:  eta: 0:09:33  iter: 1039  total_loss: 0.7237  loss_cls: 0.1762  loss_box_reg: 0.516  loss_rpn_cls: 0.004565  loss_rpn_loc: 0.01313    time: 1.2011  last_time: 1.2484  data_time: 0.0210  last_data_time: 0.0197   lr: 5e-05  max_mem: 8349M
# [02/26 07:43:08 d2.utils.events]:  eta: 0:09:08  iter: 1059  total_loss: 0.6951  loss_cls: 0.1808  loss_box_reg: 0.4845  loss_rpn_cls: 0.004297  loss_rpn_loc: 0.0144    time: 1.2011  last_time: 1.2472  data_time: 0.0208  last_data_time: 0.0181   lr: 5e-05  max_mem: 8349M
# [02/26 07:43:32 d2.utils.events]:  eta: 0:08:43  iter: 1079  total_loss: 0.6439  loss_cls: 0.1535  loss_box_reg: 0.4669  loss_rpn_cls: 0.003442  loss_rpn_loc: 0.01355    time: 1.2010  last_time: 1.0728  data_time: 0.0222  last_data_time: 0.0211   lr: 5e-05  max_mem: 8349M
# [02/26 07:43:56 d2.utils.events]:  eta: 0:08:18  iter: 1099  total_loss: 0.6079  loss_cls: 0.1409  loss_box_reg: 0.4349  loss_rpn_cls: 0.003457  loss_rpn_loc: 0.01538    time: 1.2011  last_time: 0.9268  data_time: 0.0201  last_data_time: 0.0215   lr: 5e-05  max_mem: 8349M
# [02/26 07:44:20 d2.utils.events]:  eta: 0:07:53  iter: 1119  total_loss: 0.5484  loss_cls: 0.1286  loss_box_reg: 0.4159  loss_rpn_cls: 0.004479  loss_rpn_loc: 0.01166    time: 1.2011  last_time: 1.2532  data_time: 0.0202  last_data_time: 0.0186   lr: 2.5e-06  max_mem: 8349M
# [02/26 07:44:44 d2.utils.events]:  eta: 0:07:28  iter: 1139  total_loss: 0.5874  loss_cls: 0.136  loss_box_reg: 0.4278  loss_rpn_cls: 0.00539  loss_rpn_loc: 0.01555    time: 1.2009  last_time: 1.2554  data_time: 0.0207  last_data_time: 0.0229   lr: 2.5e-06  max_mem: 8349M
# [02/26 07:45:07 d2.utils.events]:  eta: 0:07:03  iter: 1159  total_loss: 0.5909  loss_cls: 0.141  loss_box_reg: 0.4174  loss_rpn_cls: 0.00464  loss_rpn_loc: 0.01287    time: 1.2005  last_time: 1.2552  data_time: 0.0212  last_data_time: 0.0242   lr: 2.5e-06  max_mem: 8349M
# [02/26 07:45:32 d2.utils.events]:  eta: 0:06:38  iter: 1179  total_loss: 0.5601  loss_cls: 0.1285  loss_box_reg: 0.4125  loss_rpn_cls: 0.003863  loss_rpn_loc: 0.01359    time: 1.2008  last_time: 0.9841  data_time: 0.0207  last_data_time: 0.0165   lr: 2.5e-06  max_mem: 8349M
# [02/26 07:45:56 d2.utils.events]:  eta: 0:06:14  iter: 1199  total_loss: 0.5734  loss_cls: 0.1452  loss_box_reg: 0.4064  loss_rpn_cls: 0.002859  loss_rpn_loc: 0.01463    time: 1.2011  last_time: 1.2517  data_time: 0.0220  last_data_time: 0.0207   lr: 2.5e-06  max_mem: 8349M
# [02/26 07:46:20 d2.utils.events]:  eta: 0:05:49  iter: 1219  total_loss: 0.549  loss_cls: 0.1319  loss_box_reg: 0.3979  loss_rpn_cls: 0.003507  loss_rpn_loc: 0.01401    time: 1.2009  last_time: 1.2459  data_time: 0.0212  last_data_time: 0.0181   lr: 2.5e-06  max_mem: 8349M
# [02/26 07:46:44 d2.utils.events]:  eta: 0:05:24  iter: 1239  total_loss: 0.5734  loss_cls: 0.1232  loss_box_reg: 0.423  loss_rpn_cls: 0.003105  loss_rpn_loc: 0.01333    time: 1.2012  last_time: 1.2476  data_time: 0.0201  last_data_time: 0.0190   lr: 2.5e-06  max_mem: 8349M
# [02/26 07:47:08 d2.utils.events]:  eta: 0:04:59  iter: 1259  total_loss: 0.584  loss_cls: 0.1322  loss_box_reg: 0.4247  loss_rpn_cls: 0.001289  loss_rpn_loc: 0.01352    time: 1.2007  last_time: 1.2535  data_time: 0.0215  last_data_time: 0.0232   lr: 2.5e-06  max_mem: 8349M
# [02/26 07:47:32 d2.utils.events]:  eta: 0:04:34  iter: 1279  total_loss: 0.5257  loss_cls: 0.1193  loss_box_reg: 0.3949  loss_rpn_cls: 0.00242  loss_rpn_loc: 0.01337    time: 1.2007  last_time: 1.1608  data_time: 0.0204  last_data_time: 0.0195   lr: 2.5e-06  max_mem: 8349M
# [02/26 07:47:56 d2.utils.events]:  eta: 0:04:09  iter: 1299  total_loss: 0.5747  loss_cls: 0.1367  loss_box_reg: 0.4071  loss_rpn_cls: 0.003379  loss_rpn_loc: 0.01479    time: 1.2007  last_time: 1.2472  data_time: 0.0210  last_data_time: 0.0173   lr: 2.5e-06  max_mem: 8349M
# [02/26 07:48:20 d2.utils.events]:  eta: 0:03:44  iter: 1319  total_loss: 0.5582  loss_cls: 0.1442  loss_box_reg: 0.3921  loss_rpn_cls: 0.004145  loss_rpn_loc: 0.01354    time: 1.2005  last_time: 1.2608  data_time: 0.0212  last_data_time: 0.0218   lr: 2.5e-06  max_mem: 8349M
# [02/26 07:48:43 d2.utils.events]:  eta: 0:03:19  iter: 1339  total_loss: 0.5569  loss_cls: 0.1305  loss_box_reg: 0.4125  loss_rpn_cls: 0.004367  loss_rpn_loc: 0.01293    time: 1.2003  last_time: 1.2481  data_time: 0.0222  last_data_time: 0.0200   lr: 2.5e-06  max_mem: 8349M
# [02/26 07:49:07 d2.utils.events]:  eta: 0:02:54  iter: 1359  total_loss: 0.5598  loss_cls: 0.1327  loss_box_reg: 0.3949  loss_rpn_cls: 0.001779  loss_rpn_loc: 0.01533    time: 1.2000  last_time: 1.1491  data_time: 0.0213  last_data_time: 0.0203   lr: 2.5e-06  max_mem: 8349M
# [02/26 07:49:31 d2.utils.events]:  eta: 0:02:29  iter: 1379  total_loss: 0.5189  loss_cls: 0.1189  loss_box_reg: 0.3931  loss_rpn_cls: 0.001991  loss_rpn_loc: 0.01316    time: 1.1998  last_time: 1.1595  data_time: 0.0229  last_data_time: 0.0257   lr: 2.5e-06  max_mem: 8349M
# [02/26 07:49:55 d2.utils.events]:  eta: 0:02:04  iter: 1399  total_loss: 0.5703  loss_cls: 0.1299  loss_box_reg: 0.4137  loss_rpn_cls: 0.001806  loss_rpn_loc: 0.016    time: 1.1998  last_time: 1.2476  data_time: 0.0207  last_data_time: 0.0160   lr: 2.5e-06  max_mem: 8349M
# [02/26 07:50:19 d2.utils.events]:  eta: 0:01:39  iter: 1419  total_loss: 0.5469  loss_cls: 0.1199  loss_box_reg: 0.4112  loss_rpn_cls: 0.003039  loss_rpn_loc: 0.01317    time: 1.1999  last_time: 1.0730  data_time: 0.0206  last_data_time: 0.0183   lr: 2.5e-06  max_mem: 8349M
# [02/26 07:50:43 d2.utils.events]:  eta: 0:01:14  iter: 1439  total_loss: 0.5542  loss_cls: 0.1374  loss_box_reg: 0.3994  loss_rpn_cls: 0.001172  loss_rpn_loc: 0.01441    time: 1.2000  last_time: 1.1685  data_time: 0.0204  last_data_time: 0.0229   lr: 2.5e-06  max_mem: 8349M
# [02/26 07:51:07 d2.utils.events]:  eta: 0:00:49  iter: 1459  total_loss: 0.5564  loss_cls: 0.1327  loss_box_reg: 0.4107  loss_rpn_cls: 0.001912  loss_rpn_loc: 0.01181    time: 1.2000  last_time: 1.2539  data_time: 0.0211  last_data_time: 0.0152   lr: 2.5e-06  max_mem: 8349M
# [02/26 07:51:31 d2.utils.events]:  eta: 0:00:24  iter: 1479  total_loss: 0.5421  loss_cls: 0.135  loss_box_reg: 0.3853  loss_rpn_cls: 0.004344  loss_rpn_loc: 0.01506    time: 1.1997  last_time: 1.0830  data_time: 0.0217  last_data_time: 0.0180   lr: 2.5e-06  max_mem: 8349M
# [02/26 07:51:56 d2.utils.events]:  eta: 0:00:00  iter: 1499  total_loss: 0.549  loss_cls: 0.1347  loss_box_reg: 0.3923  loss_rpn_cls: 0.003377  loss_rpn_loc: 0.01556    time: 1.2000  last_time: 1.2466  data_time: 0.0216  last_data_time: 0.0169   lr: 2.5e-06  max_mem: 8349M
# [02/26 07:51:57 d2.engine.hooks]: Overall training speed: 1498 iterations in 0:29:57 (1.2000 s / it)
# [02/26 07:51:57 d2.engine.hooks]: Total training time: 0:30:04 (0:00:07 on hooks)
# WARNING [02/26 07:51:57 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [02/26 07:51:57 d2.data.datasets.coco]: Loaded 5 images in COCO format from /content/valid/_annotations.coco.json
# [02/26 07:51:57 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/26 07:51:57 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/26 07:51:57 d2.data.common]: Serializing 5 elements to byte tensors and concatenating them all ...
# [02/26 07:51:57 d2.data.common]: Serialized dataset takes 0.00 MiB
# WARNING [02/26 07:51:57 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [02/26 07:51:57 d2.evaluation.evaluator]: Start inference on 5 batches
# [02/26 07:51:58 d2.evaluation.evaluator]: Total inference time: 0:00:00.105454 (0.105454 s / iter per device, on 1 devices)
# [02/26 07:51:58 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:00 (0.073928 s / iter per device, on 1 devices)
# [02/26 07:51:58 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/26 07:51:58 d2.evaluation.coco_evaluation]: Saving results to coco_eval/coco_instances_results.json
# [02/26 07:51:58 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [02/26 07:51:58 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [02/26 07:51:58 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.00 seconds.
# [02/26 07:51:58 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [02/26 07:51:58 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.02 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.558
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.862
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.673
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.510
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.569
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.487
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.675
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.675
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.550
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.733
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# [02/26 07:51:58 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl  |
# |:------:|:------:|:------:|:------:|:------:|:-----:|
# | 55.789 | 86.221 | 67.325 | 50.974 | 56.913 |  nan  |
# [02/26 07:51:58 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/26 07:51:58 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category     | AP     | category      | AP     | category    | AP     |
# |:-------------|:-------|:--------------|:-------|:------------|:-------|
# | symbols      | nan    | Gate_valve    | 39.658 | S_21_Flange | 50.099 |
# | S_28_SDL-DDL | 80.000 | Sliding_valve | 53.399 | th          | nan    |
# [02/26 07:51:58 d2.engine.defaults]: Evaluation results for my_dataset_val in csv format:
# [02/26 07:51:58 d2.evaluation.testing]: copypaste: Task: bbox
# [02/26 07:51:58 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/26 07:51:58 d2.evaluation.testing]: copypaste: 55.7892,86.2211,67.3252,50.9736,56.9134,nan

# %%
# Look at training curves in tensorboard:
# %load_ext tensorboard
# %tensorboard --logdir output

# %%
#test evaluation
from detectron2.data import DatasetCatalog, MetadataCatalog, build_detection_test_loader
from detectron2.evaluation import COCOEvaluator, inference_on_dataset

cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.85
predictor = DefaultPredictor(cfg)
evaluator = COCOEvaluator("my_dataset_test", cfg, False, output_dir="./output/")
val_loader = build_detection_test_loader(cfg, "my_dataset_test")
inference_on_dataset(trainer.model, val_loader, evaluator)
# Out:
# [02/26 07:52:00 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./output/model_final.pth ...
# WARNING [02/26 07:52:00 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# WARNING [02/26 07:52:00 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [02/26 07:52:00 d2.data.datasets.coco]: Loaded 7 images in COCO format from /content/test/_annotations.coco.json
# [02/26 07:52:00 d2.data.build]: Distribution of instances among all 6 categories:
# |   category   | #instances   |   category    | #instances   |  category   | #instances   |
# |:------------:|:-------------|:-------------:|:-------------|:-----------:|:-------------|
# |   symbols    | 0            |  Gate_valve   | 4            | S_21_Flange | 5            |
# | S_28_SDL-DDL | 4            | Sliding_valve | 5            |     th      | 4            |
# |              |              |               |              |             |              |
# |    total     | 22           |               |              |             |              |
# [02/26 07:52:00 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/26 07:52:00 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/26 07:52:00 d2.data.common]: Serializing 7 elements to byte tensors and concatenating them all ...
# [02/26 07:52:00 d2.data.common]: Serialized dataset takes 0.00 MiB
# [02/26 07:52:00 d2.evaluation.evaluator]: Start inference on 7 batches
# [02/26 07:52:01 d2.evaluation.evaluator]: Total inference time: 0:00:00.182924 (0.091462 s / iter per device, on 1 devices)
# [02/26 07:52:01 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:00 (0.071517 s / iter per device, on 1 devices)
# [02/26 07:52:01 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/26 07:52:01 d2.evaluation.coco_evaluation]: Saving results to ./output/coco_instances_results.json
# [02/26 07:52:01 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [02/26 07:52:01 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [02/26 07:52:01 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.01 seconds.
# [02/26 07:52:01 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [02/26 07:52:01 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.474
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.824
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.440
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.465
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.505
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.321
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.583
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.583
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.540
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.609
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# [02/26 07:52:01 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl  |
# |:------:|:------:|:------:|:------:|:------:|:-----:|
# | 47.371 | 82.377 | 44.017 | 46.510 | 50.511 |  nan  |
# [02/26 07:52:01 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/26 07:52:01 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category     | AP     | category      | AP     | category    | AP     |
# |:-------------|:-------|:--------------|:-------|:------------|:-------|
# | symbols      | nan    | Gate_valve    | 49.598 | S_21_Flange | 46.782 |
# | S_28_SDL-DDL | 65.287 | Sliding_valve | 56.738 | th          | 18.449 |
# OrderedDict([('bbox',
#               {'AP': 47.370857085708565,
#                'AP50': 82.37663766376639,
#                'AP75': 44.016801680168015,
#                'APs': 46.50990099009901,
#                'APm': 50.51143328618577,
#                'APl': nan,
#                'AP-symbols': nan,
#                'AP-Gate_valve': 49.59795979597959,
#                'AP-S_21_Flange': 46.78217821782179,
#                'AP-S_28_SDL-DDL': 65.2871287128713,
#                'AP-Sliding_valve': 56.738173817381735,
#                'AP-th': 18.448844884488448})])

# %% [markdown]
# # Inference with Detectron2 Saved Weights

# %%
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")
cfg.DATASETS.TEST = ("my_dataset_test", )
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.7   # set the testing threshold for this model
predictor = DefaultPredictor(cfg)
test_metadata = MetadataCatalog.get("my_dataset_test")
# Out:
# [02/26 07:52:03 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./output/model_final.pth ...

# %%
from detectron2.utils.visualizer import ColorMode
import glob

for imageName in glob.glob('/content/test/*jpg'):
  im = cv2.imread(imageName)
  outputs = predictor(im)
  v = Visualizer(im[:, :, ::-1],
                metadata=test_metadata,
                scale=0.8
                 )
  out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
  cv2_imshow(out.get_image()[:, :, ::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
# <PIL.Image.Image image mode=RGB size=512x512>
# <PIL.Image.Image image mode=RGB size=512x512>
# <PIL.Image.Image image mode=RGB size=512x512>
# <PIL.Image.Image image mode=RGB size=512x512>
# <PIL.Image.Image image mode=RGB size=512x512>
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mv "/content/test" "/content/drive/MyDrive/test1"

# %%
# !mv "/content/train" "/content/drive/MyDrive/train1"

# %%
# !mv "/content/valid" "/content/drive/MyDrive/valid1"

# %%
# !mv "/content/coco_eval" "/content/drive/MyDrive/coco_eval1"

# %%
# !mv "/content/drive/MyDrive/output1/model_final.pth" "/content/drive/MyDrive/output1/model_path"
# Out:
# mv: cannot stat '/content/drive/MyDrive/output1/model_final.pth': No such file or directory

# %%
from detectron2.utils.visualizer import ColorMode
import glob

for imageName in glob.glob('/content/test/th1.jpg'):
  im = cv2.imread(imageName)
  outputs = predictor(im)
  v = Visualizer(im[:, :, ::-1],
                metadata=test_metadata,
                scale=0.8
                 )
  out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
  cv2_imshow(out.get_image()[:, :, ::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=360x232>
